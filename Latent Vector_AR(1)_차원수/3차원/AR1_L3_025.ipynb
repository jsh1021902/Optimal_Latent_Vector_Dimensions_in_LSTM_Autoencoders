# %%
import numpy as np
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from pytorchtools import EarlyStopping
import math
from tqdm import tqdm
import statsmodels.api as sm
import seaborn as sns

# %% [markdown]
# #### Numpy & Python Version 확인

# %%
import numpy as np
import platform

# NumPy 버전 확인
numpy_version = np.__version__

# Python 버전 확인
python_version = platform.python_version()

print(f"NumPy 버전: {numpy_version}")
print(f"Python 버전: {python_version}")
# Out:
# NumPy 버전: 1.26.4
# Python 버전: 3.11.9

# %% [markdown]
# #### CUDA 사용 및 EarlyStopping 설정

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
print(device)
early_stopping = EarlyStopping(patience = 5, verbose = True)
# Out:
# cpu

# %% [markdown]
# #### 모델 저장

# %%
def saveModel():
    torch.save(model.state_dict(), 'ARL1_L3_025.pt') # 모델의 학습된 매개변수 파일에 저장

# %% [markdown]
# #### 하이퍼 파라미터 설정

# %%
# 하이퍼파라미터 설정
length = 12             # 윈도우 사이즈 (생성할 시계열 데이터의 길이)
trainrun = 2000         # 생성할 학습 데이터 시퀀스의 수 
validrun = 1000         # 생성할 검증 데이터 시퀀스의 수 

# 시계열 데이터 생성을 위한 매개변수
# 자기상관계수 (phi값을 0.25로 생성)
phi1 = np.array([0.25])

# 공정의 수준 변화율 (delta)
de1 = 0

# 공정의 분산 변화율 (gamma)
ga = 1

# %% [markdown]
# #### 시계열 데이터 생성

# %%
np.random.seed(1)

# AR(1) 시계열 데이터 생성 함수
def ar(ar1, delta, gamma, length, run):
    # 초기 설정
    y = np.zeros(shape=(run, length))                           # 생성될 시계열 데이터를 저장할 빈 배열을 초기화. 배열의 크기는 (생성할 데이터 시퀀스의 수, 각 시퀀스의 길이) 
    sigma = math.sqrt(1 / (1 - pow(ar1, 2)))                    # AR(1)모델의 표준 편차
    
    # 데이터 시퀀스 생성
    for j in range(0, run):                                     # 각 run 마다 랜덤 노이즈(e)를 정규분포에서 추출하여 시계열의 기본 노이즈 생성 (과적합 방지 차원)
        e = np.random.normal(loc=0, scale=1, size=length)       
        x = np.zeros(length)
        
        x[0] = e[0]                                             # x 배열 초기화하고, 첫 번째 시점의 값은 첫 번째 노이즈 값으로 설정 (시계열의 시작점에서 발생할 수 있는 임의성 반영 및 자기상관 구조 구현)
        
        for t in range(1, length):
            x[t] = ar1 * x[t - 1] + e[t]                        # 관리상태 시계열 데이터 생성
                               
        # 최종 데이터 반환 (각 run에 대해 생성된 시계열 데이터를 저장)  
        y[j] = x

    return y


# 다양한 매개변수 조합에 대한 시계열 데이터 세트 생성
def totaldat(run,length):
    # 빈 데이터 배열 초기화
    y = np.zeros(shape=(len(phi1), run, length))
    # 매개변수 조합별 데이터 생성
    for i, phi in enumerate(phi1):
        y[i]= ar(phi, de1, ga, length, run)

    return y.reshape(run * len(phi1), length)                   # 생성된 데이터를 적절한 형태로 재배열

# %%
# 훈련용 시계열 데이터
# 데이터 생성 및 변형
train_x = totaldat(trainrun,length)                             # 훈련용 시계열 데이터 생성
train_x = train_x.reshape(trainrun*len(phi1),length)            

# 검증용 시계열 데이터
# 데이터 생성 및 변형
valid_x = totaldat(run = validrun, length = length)
valid_x = valid_x.reshape(validrun*len(phi1),length)

# PyTorch 텐서로 변환 및 장치 할당
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_x = torch.FloatTensor(train_x).to(device)
valid_x = torch.FloatTensor(valid_x).to(device)

# DataLoader 설정
trainloader = DataLoader(train_x, shuffle=True)                 # 데이터셋에서 미니배치 자동으로 생성 후 모델 학습 및 평가 시 배치 처리를 용이하게 함 (훈련에서는 데이터를 섞어 학습 과정에서의 일반화 능력 향상)
validloader = DataLoader(valid_x, shuffle=False)                # 학습 및 검증에서는 데이터 순서 유지

# %%
for data in trainloader:
    print(data.shape)
    break
# Out:
# torch.Size([1, 12])

# %%
len(trainloader)
# Out:
# 2000

# %%
len(validloader)
# Out:
# 1000

# %%
train_x.shape[1]
# Out:
# 12

# %% [markdown]
# #### LSTM Autoencoder 구조

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# Encoder 클래스 정의
class Encoder(nn.Module):
    def __init__(self, seq_length, latent_dim, input_dim):
        super(Encoder, self).__init__()
        self.lstm1 = nn.LSTM(input_size=input_dim, hidden_size=128, num_layers=1, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=128, hidden_size=latent_dim, num_layers=1, batch_first=True)
        self.seq_length = seq_length

    def forward(self, x):
        x, _ = self.lstm1(x)
        z, _ = self.lstm2(x)
        z_rep = z.unsqueeze(1).repeat(1, self.seq_length, 1)  # (batch_size, seq_length, latent_dim)
        return z, z_rep

# Decoder 클래스 정의
class Decoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Decoder, self).__init__()
        self.lstm1 = nn.LSTM(input_size=latent_dim, hidden_size=128, num_layers=1, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=128, hidden_size=128, num_layers=1, batch_first=True)
        self.time_distributed = nn.Linear(128, input_dim)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x = self.time_distributed(x)
        return x

# 전체 LSTM 오토인코더 모델 정의
class LstmAE(nn.Module):
    def __init__(self, seq_length, input_dim, latent_dim):
        super(LstmAE, self).__init__()
        self.encoder = Encoder(seq_length, latent_dim, input_dim)
        self.decoder = Decoder(input_dim, latent_dim)

    def forward(self, x):
        z, z_rep = self.encoder(x)
        decoded = self.decoder(z_rep)
        return decoded

# 모델 인스턴스 생성 및 설정
seq_length = 12  # 시퀀스 길이
input_dim = 12   # 입력 차원
latent_dim = 3   # 잠재 차원

# 모델 인스턴스 생성 및 설정
model = LstmAE(seq_length=seq_length, input_dim=input_dim, latent_dim=latent_dim)
model = model.to(device)

# %%
import torch.optim as optim

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-6)
def training(epochs):
    loss_ = []
    valoss_ = []

    for epoch in range(epochs):
        running_train_loss = 0.0
        running_vall_loss = 0.0

        # Training process
        for data in trainloader:
            model.train()
            inputs = data                                                           # Assuming data is the input tensor
            inputs = inputs.to(device)
            optimizer.zero_grad()
            predicted_outputs = model(inputs)
            train_loss = criterion(predicted_outputs, inputs)
            train_loss.backward()
            optimizer.step()
            running_train_loss += train_loss.item()

        # Calculate average training loss for the epoch
        avg_train_loss = running_train_loss / len(trainloader)
        loss_.append(avg_train_loss)
        
        # Validation process
        with torch.no_grad():
            model.eval()
            for data in validloader:
                inputs = data
                inputs = inputs.to(device)
                predicted_outputs = model(inputs)
                val_loss = criterion(predicted_outputs, inputs)
                running_vall_loss += val_loss.item()

            avg_val_loss = running_vall_loss / len(validloader)
            valoss_.append(avg_val_loss)

        print(f'Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}')
        
        # Early Stopping
        early_stopping(avg_val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break

    # Save model
    saveModel()
    return loss_, valoss_  # Return the collected loss values for training and validation

# Now when you call training, it will return the lists to be unpacked.
loss_, valoss_ = training(epochs = 400)  # Set the appropriate number of epochs
# Out:
# /Users/leeseungmin/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1, 12])) that is different to the input size (torch.Size([1, 12, 12])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1, Train Loss: 1.0568, Validation Loss: 1.0580
# Validation loss decreased (inf --> 1.058005).  Saving model ...
# Epoch 2, Train Loss: 1.0567, Validation Loss: 1.0578
# Validation loss decreased (1.058005 --> 1.057842).  Saving model ...
# Epoch 3, Train Loss: 1.0565, Validation Loss: 1.0577
# Validation loss decreased (1.057842 --> 1.057682).  Saving model ...
# Epoch 4, Train Loss: 1.0564, Validation Loss: 1.0575
# Validation loss decreased (1.057682 --> 1.057527).  Saving model ...
# Epoch 5, Train Loss: 1.0563, Validation Loss: 1.0574
# Validation loss decreased (1.057527 --> 1.057380).  Saving model ...
# Epoch 6, Train Loss: 1.0561, Validation Loss: 1.0572
# Validation loss decreased (1.057380 --> 1.057230).  Saving model ...
# Epoch 7, Train Loss: 1.0560, Validation Loss: 1.0571
# Validation loss decreased (1.057230 --> 1.057085).  Saving model ...
# Epoch 8, Train Loss: 1.0559, Validation Loss: 1.0569
# Validation loss decreased (1.057085 --> 1.056942).  Saving model ...
# Epoch 9, Train Loss: 1.0557, Validation Loss: 1.0568
# Validation loss decreased (1.056942 --> 1.056801).  Saving model ...
# Epoch 10, Train Loss: 1.0556, Validation Loss: 1.0567
# Validation loss decreased (1.056801 --> 1.056659).  Saving model ...
# Epoch 11, Train Loss: 1.0555, Validation Loss: 1.0565
# Validation loss decreased (1.056659 --> 1.056517).  Saving model ...
# Epoch 12, Train Loss: 1.0553, Validation Loss: 1.0564
# Validation loss decreased (1.056517 --> 1.056373).  Saving model ...
# Epoch 13, Train Loss: 1.0552, Validation Loss: 1.0562
# Validation loss decreased (1.056373 --> 1.056230).  Saving model ...
# Epoch 14, Train Loss: 1.0551, Validation Loss: 1.0561
# Validation loss decreased (1.056230 --> 1.056082).  Saving model ...
# Epoch 15, Train Loss: 1.0549, Validation Loss: 1.0559
# Validation loss decreased (1.056082 --> 1.055931).  Saving model ...
# Epoch 16, Train Loss: 1.0548, Validation Loss: 1.0558
# Validation loss decreased (1.055931 --> 1.055774).  Saving model ...
# Epoch 17, Train Loss: 1.0546, Validation Loss: 1.0556
# Validation loss decreased (1.055774 --> 1.055611).  Saving model ...
# Epoch 18, Train Loss: 1.0545, Validation Loss: 1.0554
# Validation loss decreased (1.055611 --> 1.055441).  Saving model ...
# Epoch 19, Train Loss: 1.0543, Validation Loss: 1.0553
# Validation loss decreased (1.055441 --> 1.055265).  Saving model ...
# Epoch 20, Train Loss: 1.0541, Validation Loss: 1.0551
# Validation loss decreased (1.055265 --> 1.055073).  Saving model ...
# Epoch 21, Train Loss: 1.0540, Validation Loss: 1.0549
# Validation loss decreased (1.055073 --> 1.054871).  Saving model ...
# Epoch 22, Train Loss: 1.0538, Validation Loss: 1.0547
# Validation loss decreased (1.054871 --> 1.054656).  Saving model ...
# Epoch 23, Train Loss: 1.0535, Validation Loss: 1.0544
# Validation loss decreased (1.054656 --> 1.054423).  Saving model ...
# Epoch 24, Train Loss: 1.0533, Validation Loss: 1.0542
# Validation loss decreased (1.054423 --> 1.054170).  Saving model ...
# Epoch 25, Train Loss: 1.0530, Validation Loss: 1.0539
# Validation loss decreased (1.054170 --> 1.053897).  Saving model ...
# Epoch 26, Train Loss: 1.0528, Validation Loss: 1.0536
# Validation loss decreased (1.053897 --> 1.053594).  Saving model ...
# Epoch 27, Train Loss: 1.0524, Validation Loss: 1.0533
# Validation loss decreased (1.053594 --> 1.053258).  Saving model ...
# Epoch 28, Train Loss: 1.0521, Validation Loss: 1.0529
# Validation loss decreased (1.053258 --> 1.052881).  Saving model ...
# Epoch 29, Train Loss: 1.0517, Validation Loss: 1.0525
# Validation loss decreased (1.052881 --> 1.052464).  Saving model ...
# Epoch 30, Train Loss: 1.0513, Validation Loss: 1.0520
# Validation loss decreased (1.052464 --> 1.051987).  Saving model ...
# Epoch 31, Train Loss: 1.0507, Validation Loss: 1.0514
# Validation loss decreased (1.051987 --> 1.051448).  Saving model ...
# Epoch 32, Train Loss: 1.0502, Validation Loss: 1.0508
# Validation loss decreased (1.051448 --> 1.050828).  Saving model ...
# Epoch 33, Train Loss: 1.0495, Validation Loss: 1.0501
# Validation loss decreased (1.050828 --> 1.050109).  Saving model ...
# Epoch 34, Train Loss: 1.0487, Validation Loss: 1.0493
# Validation loss decreased (1.050109 --> 1.049267).  Saving model ...
# Epoch 35, Train Loss: 1.0478, Validation Loss: 1.0483
# Validation loss decreased (1.049267 --> 1.048288).  Saving model ...
# Epoch 36, Train Loss: 1.0467, Validation Loss: 1.0471
# Validation loss decreased (1.048288 --> 1.047112).  Saving model ...
# Epoch 37, Train Loss: 1.0454, Validation Loss: 1.0457
# Validation loss decreased (1.047112 --> 1.045718).  Saving model ...
# Epoch 38, Train Loss: 1.0438, Validation Loss: 1.0440
# Validation loss decreased (1.045718 --> 1.044012).  Saving model ...
# Epoch 39, Train Loss: 1.0419, Validation Loss: 1.0419
# Validation loss decreased (1.044012 --> 1.041945).  Saving model ...
# Epoch 40, Train Loss: 1.0396, Validation Loss: 1.0394
# Validation loss decreased (1.041945 --> 1.039383).  Saving model ...
# Epoch 41, Train Loss: 1.0367, Validation Loss: 1.0362
# Validation loss decreased (1.039383 --> 1.036206).  Saving model ...
# Epoch 42, Train Loss: 1.0330, Validation Loss: 1.0323
# Validation loss decreased (1.036206 --> 1.032275).  Saving model ...
# Epoch 43, Train Loss: 1.0285, Validation Loss: 1.0274
# Validation loss decreased (1.032275 --> 1.027374).  Saving model ...
# Epoch 44, Train Loss: 1.0230, Validation Loss: 1.0214
# Validation loss decreased (1.027374 --> 1.021380).  Saving model ...
# Epoch 45, Train Loss: 1.0162, Validation Loss: 1.0142
# Validation loss decreased (1.021380 --> 1.014243).  Saving model ...
# Epoch 46, Train Loss: 1.0085, Validation Loss: 1.0064
# Validation loss decreased (1.014243 --> 1.006388).  Saving model ...
# Epoch 47, Train Loss: 1.0004, Validation Loss: 0.9986
# Validation loss decreased (1.006388 --> 0.998565).  Saving model ...
# Epoch 48, Train Loss: 0.9928, Validation Loss: 0.9919
# Validation loss decreased (0.998565 --> 0.991880).  Saving model ...
# Epoch 49, Train Loss: 0.9869, Validation Loss: 0.9872
# Validation loss decreased (0.991880 --> 0.987208).  Saving model ...
# Epoch 50, Train Loss: 0.9830, Validation Loss: 0.9844
# Validation loss decreased (0.987208 --> 0.984431).  Saving model ...
# Epoch 51, Train Loss: 0.9807, Validation Loss: 0.9828
# Validation loss decreased (0.984431 --> 0.982782).  Saving model ...
# Epoch 52, Train Loss: 0.9792, Validation Loss: 0.9817
# Validation loss decreased (0.982782 --> 0.981662).  Saving model ...
# Epoch 53, Train Loss: 0.9781, Validation Loss: 0.9808
# Validation loss decreased (0.981662 --> 0.980768).  Saving model ...
# Epoch 54, Train Loss: 0.9772, Validation Loss: 0.9799
# Validation loss decreased (0.980768 --> 0.979943).  Saving model ...
# Epoch 55, Train Loss: 0.9763, Validation Loss: 0.9792
# Validation loss decreased (0.979943 --> 0.979157).  Saving model ...
# Epoch 56, Train Loss: 0.9754, Validation Loss: 0.9784
# Validation loss decreased (0.979157 --> 0.978397).  Saving model ...
# Epoch 57, Train Loss: 0.9746, Validation Loss: 0.9777
# Validation loss decreased (0.978397 --> 0.977665).  Saving model ...
# Epoch 58, Train Loss: 0.9738, Validation Loss: 0.9769
# Validation loss decreased (0.977665 --> 0.976949).  Saving model ...
# Epoch 59, Train Loss: 0.9730, Validation Loss: 0.9762
# Validation loss decreased (0.976949 --> 0.976236).  Saving model ...
# Epoch 60, Train Loss: 0.9722, Validation Loss: 0.9755
# Validation loss decreased (0.976236 --> 0.975534).  Saving model ...
# Epoch 61, Train Loss: 0.9714, Validation Loss: 0.9748
# Validation loss decreased (0.975534 --> 0.974841).  Saving model ...
# Epoch 62, Train Loss: 0.9707, Validation Loss: 0.9741
# Validation loss decreased (0.974841 --> 0.974145).  Saving model ...
# Epoch 63, Train Loss: 0.9699, Validation Loss: 0.9735
# Validation loss decreased (0.974145 --> 0.973462).  Saving model ...
# Epoch 64, Train Loss: 0.9691, Validation Loss: 0.9728
# Validation loss decreased (0.973462 --> 0.972774).  Saving model ...
# Epoch 65, Train Loss: 0.9684, Validation Loss: 0.9721
# Validation loss decreased (0.972774 --> 0.972079).  Saving model ...
# Epoch 66, Train Loss: 0.9676, Validation Loss: 0.9714
# Validation loss decreased (0.972079 --> 0.971379).  Saving model ...
# Epoch 67, Train Loss: 0.9668, Validation Loss: 0.9707
# Validation loss decreased (0.971379 --> 0.970673).  Saving model ...
# Epoch 68, Train Loss: 0.9661, Validation Loss: 0.9700
# Validation loss decreased (0.970673 --> 0.969957).  Saving model ...
# Epoch 69, Train Loss: 0.9653, Validation Loss: 0.9692
# Validation loss decreased (0.969957 --> 0.969226).  Saving model ...
# Epoch 70, Train Loss: 0.9645, Validation Loss: 0.9685
# Validation loss decreased (0.969226 --> 0.968474).  Saving model ...
# Epoch 71, Train Loss: 0.9637, Validation Loss: 0.9677
# Validation loss decreased (0.968474 --> 0.967718).  Saving model ...
# Epoch 72, Train Loss: 0.9628, Validation Loss: 0.9669
# Validation loss decreased (0.967718 --> 0.966941).  Saving model ...
# Epoch 73, Train Loss: 0.9620, Validation Loss: 0.9661
# Validation loss decreased (0.966941 --> 0.966128).  Saving model ...
# Epoch 74, Train Loss: 0.9611, Validation Loss: 0.9653
# Validation loss decreased (0.966128 --> 0.965286).  Saving model ...
# Epoch 75, Train Loss: 0.9602, Validation Loss: 0.9644
# Validation loss decreased (0.965286 --> 0.964415).  Saving model ...
# Epoch 76, Train Loss: 0.9592, Validation Loss: 0.9635
# Validation loss decreased (0.964415 --> 0.963502).  Saving model ...
# Epoch 77, Train Loss: 0.9582, Validation Loss: 0.9625
# Validation loss decreased (0.963502 --> 0.962542).  Saving model ...
# Epoch 78, Train Loss: 0.9572, Validation Loss: 0.9615
# Validation loss decreased (0.962542 --> 0.961528).  Saving model ...
# Epoch 79, Train Loss: 0.9561, Validation Loss: 0.9604
# Validation loss decreased (0.961528 --> 0.960444).  Saving model ...
# Epoch 80, Train Loss: 0.9549, Validation Loss: 0.9593
# Validation loss decreased (0.960444 --> 0.959290).  Saving model ...
# Epoch 81, Train Loss: 0.9536, Validation Loss: 0.9581
# Validation loss decreased (0.959290 --> 0.958055).  Saving model ...
# Epoch 82, Train Loss: 0.9523, Validation Loss: 0.9567
# Validation loss decreased (0.958055 --> 0.956718).  Saving model ...
# Epoch 83, Train Loss: 0.9508, Validation Loss: 0.9553
# Validation loss decreased (0.956718 --> 0.955273).  Saving model ...
# Epoch 84, Train Loss: 0.9493, Validation Loss: 0.9537
# Validation loss decreased (0.955273 --> 0.953704).  Saving model ...
# Epoch 85, Train Loss: 0.9476, Validation Loss: 0.9520
# Validation loss decreased (0.953704 --> 0.951983).  Saving model ...
# Epoch 86, Train Loss: 0.9457, Validation Loss: 0.9501
# Validation loss decreased (0.951983 --> 0.950108).  Saving model ...
# Epoch 87, Train Loss: 0.9437, Validation Loss: 0.9481
# Validation loss decreased (0.950108 --> 0.948059).  Saving model ...
# Epoch 88, Train Loss: 0.9415, Validation Loss: 0.9458
# Validation loss decreased (0.948059 --> 0.945848).  Saving model ...
# Epoch 89, Train Loss: 0.9391, Validation Loss: 0.9435
# Validation loss decreased (0.945848 --> 0.943463).  Saving model ...
# Epoch 90, Train Loss: 0.9366, Validation Loss: 0.9409
# Validation loss decreased (0.943463 --> 0.940948).  Saving model ...
# Epoch 91, Train Loss: 0.9339, Validation Loss: 0.9383
# Validation loss decreased (0.940948 --> 0.938307).  Saving model ...
# Epoch 92, Train Loss: 0.9311, Validation Loss: 0.9356
# Validation loss decreased (0.938307 --> 0.935581).  Saving model ...
# Epoch 93, Train Loss: 0.9283, Validation Loss: 0.9328
# Validation loss decreased (0.935581 --> 0.932842).  Saving model ...
# Epoch 94, Train Loss: 0.9254, Validation Loss: 0.9301
# Validation loss decreased (0.932842 --> 0.930117).  Saving model ...
# Epoch 95, Train Loss: 0.9226, Validation Loss: 0.9275
# Validation loss decreased (0.930117 --> 0.927499).  Saving model ...
# Epoch 96, Train Loss: 0.9199, Validation Loss: 0.9250
# Validation loss decreased (0.927499 --> 0.925025).  Saving model ...
# Epoch 97, Train Loss: 0.9174, Validation Loss: 0.9227
# Validation loss decreased (0.925025 --> 0.922735).  Saving model ...
# Epoch 98, Train Loss: 0.9150, Validation Loss: 0.9207
# Validation loss decreased (0.922735 --> 0.920667).  Saving model ...
# Epoch 99, Train Loss: 0.9129, Validation Loss: 0.9188
# Validation loss decreased (0.920667 --> 0.918815).  Saving model ...
# Epoch 100, Train Loss: 0.9110, Validation Loss: 0.9172
# Validation loss decreased (0.918815 --> 0.917167).  Saving model ...
# Epoch 101, Train Loss: 0.9093, Validation Loss: 0.9157
# Validation loss decreased (0.917167 --> 0.915717).  Saving model ...
# Epoch 102, Train Loss: 0.9077, Validation Loss: 0.9144
# Validation loss decreased (0.915717 --> 0.914430).  Saving model ...
# Epoch 103, Train Loss: 0.9064, Validation Loss: 0.9133
# Validation loss decreased (0.914430 --> 0.913269).  Saving model ...
# Epoch 104, Train Loss: 0.9051, Validation Loss: 0.9122
# Validation loss decreased (0.913269 --> 0.912213).  Saving model ...
# Epoch 105, Train Loss: 0.9040, Validation Loss: 0.9112
# Validation loss decreased (0.912213 --> 0.911235).  Saving model ...
# Epoch 106, Train Loss: 0.9029, Validation Loss: 0.9103
# Validation loss decreased (0.911235 --> 0.910338).  Saving model ...
# Epoch 107, Train Loss: 0.9019, Validation Loss: 0.9095
# Validation loss decreased (0.910338 --> 0.909483).  Saving model ...
# Epoch 108, Train Loss: 0.9009, Validation Loss: 0.9087
# Validation loss decreased (0.909483 --> 0.908688).  Saving model ...
# Epoch 109, Train Loss: 0.9001, Validation Loss: 0.9079
# Validation loss decreased (0.908688 --> 0.907927).  Saving model ...
# Epoch 110, Train Loss: 0.8992, Validation Loss: 0.9072
# Validation loss decreased (0.907927 --> 0.907208).  Saving model ...
# Epoch 111, Train Loss: 0.8984, Validation Loss: 0.9065
# Validation loss decreased (0.907208 --> 0.906514).  Saving model ...
# Epoch 112, Train Loss: 0.8976, Validation Loss: 0.9058
# Validation loss decreased (0.906514 --> 0.905840).  Saving model ...
# Epoch 113, Train Loss: 0.8969, Validation Loss: 0.9052
# Validation loss decreased (0.905840 --> 0.905199).  Saving model ...
# Epoch 114, Train Loss: 0.8961, Validation Loss: 0.9046
# Validation loss decreased (0.905199 --> 0.904562).  Saving model ...
# Epoch 115, Train Loss: 0.8954, Validation Loss: 0.9040
# Validation loss decreased (0.904562 --> 0.903951).  Saving model ...
# Epoch 116, Train Loss: 0.8947, Validation Loss: 0.9033
# Validation loss decreased (0.903951 --> 0.903348).  Saving model ...
# Epoch 117, Train Loss: 0.8940, Validation Loss: 0.9028
# Validation loss decreased (0.903348 --> 0.902764).  Saving model ...
# Epoch 118, Train Loss: 0.8934, Validation Loss: 0.9022
# Validation loss decreased (0.902764 --> 0.902186).  Saving model ...
# Epoch 119, Train Loss: 0.8927, Validation Loss: 0.9016
# Validation loss decreased (0.902186 --> 0.901621).  Saving model ...
# Epoch 120, Train Loss: 0.8921, Validation Loss: 0.9011
# Validation loss decreased (0.901621 --> 0.901070).  Saving model ...
# Epoch 121, Train Loss: 0.8915, Validation Loss: 0.9005
# Validation loss decreased (0.901070 --> 0.900523).  Saving model ...
# Epoch 122, Train Loss: 0.8908, Validation Loss: 0.9000
# Validation loss decreased (0.900523 --> 0.899984).  Saving model ...
# Epoch 123, Train Loss: 0.8902, Validation Loss: 0.8995
# Validation loss decreased (0.899984 --> 0.899452).  Saving model ...
# Epoch 124, Train Loss: 0.8896, Validation Loss: 0.8989
# Validation loss decreased (0.899452 --> 0.898926).  Saving model ...
# Epoch 125, Train Loss: 0.8890, Validation Loss: 0.8984
# Validation loss decreased (0.898926 --> 0.898410).  Saving model ...
# Epoch 126, Train Loss: 0.8884, Validation Loss: 0.8979
# Validation loss decreased (0.898410 --> 0.897891).  Saving model ...
# Epoch 127, Train Loss: 0.8878, Validation Loss: 0.8974
# Validation loss decreased (0.897891 --> 0.897387).  Saving model ...
# Epoch 128, Train Loss: 0.8873, Validation Loss: 0.8969
# Validation loss decreased (0.897387 --> 0.896874).  Saving model ...
# Epoch 129, Train Loss: 0.8867, Validation Loss: 0.8964
# Validation loss decreased (0.896874 --> 0.896379).  Saving model ...
# Epoch 130, Train Loss: 0.8861, Validation Loss: 0.8959
# Validation loss decreased (0.896379 --> 0.895886).  Saving model ...
# Epoch 131, Train Loss: 0.8856, Validation Loss: 0.8954
# Validation loss decreased (0.895886 --> 0.895397).  Saving model ...
# Epoch 132, Train Loss: 0.8850, Validation Loss: 0.8949
# Validation loss decreased (0.895397 --> 0.894915).  Saving model ...
# Epoch 133, Train Loss: 0.8845, Validation Loss: 0.8944
# Validation loss decreased (0.894915 --> 0.894436).  Saving model ...
# Epoch 134, Train Loss: 0.8839, Validation Loss: 0.8940
# Validation loss decreased (0.894436 --> 0.893962).  Saving model ...
# Epoch 135, Train Loss: 0.8834, Validation Loss: 0.8935
# Validation loss decreased (0.893962 --> 0.893486).  Saving model ...
# Epoch 136, Train Loss: 0.8828, Validation Loss: 0.8930
# Validation loss decreased (0.893486 --> 0.893018).  Saving model ...
# Epoch 137, Train Loss: 0.8823, Validation Loss: 0.8926
# Validation loss decreased (0.893018 --> 0.892562).  Saving model ...
# Epoch 138, Train Loss: 0.8818, Validation Loss: 0.8921
# Validation loss decreased (0.892562 --> 0.892098).  Saving model ...
# Epoch 139, Train Loss: 0.8812, Validation Loss: 0.8916
# Validation loss decreased (0.892098 --> 0.891646).  Saving model ...
# Epoch 140, Train Loss: 0.8807, Validation Loss: 0.8912
# Validation loss decreased (0.891646 --> 0.891205).  Saving model ...
# Epoch 141, Train Loss: 0.8802, Validation Loss: 0.8908
# Validation loss decreased (0.891205 --> 0.890752).  Saving model ...
# Epoch 142, Train Loss: 0.8797, Validation Loss: 0.8903
# Validation loss decreased (0.890752 --> 0.890316).  Saving model ...
# Epoch 143, Train Loss: 0.8792, Validation Loss: 0.8899
# Validation loss decreased (0.890316 --> 0.889884).  Saving model ...
# Epoch 144, Train Loss: 0.8787, Validation Loss: 0.8895
# Validation loss decreased (0.889884 --> 0.889455).  Saving model ...
# Epoch 145, Train Loss: 0.8782, Validation Loss: 0.8890
# Validation loss decreased (0.889455 --> 0.889027).  Saving model ...
# Epoch 146, Train Loss: 0.8777, Validation Loss: 0.8886
# Validation loss decreased (0.889027 --> 0.888609).  Saving model ...
# Epoch 147, Train Loss: 0.8772, Validation Loss: 0.8882
# Validation loss decreased (0.888609 --> 0.888205).  Saving model ...
# Epoch 148, Train Loss: 0.8767, Validation Loss: 0.8878
# Validation loss decreased (0.888205 --> 0.887791).  Saving model ...
# Epoch 149, Train Loss: 0.8763, Validation Loss: 0.8874
# Validation loss decreased (0.887791 --> 0.887379).  Saving model ...
# Epoch 150, Train Loss: 0.8758, Validation Loss: 0.8870
# Validation loss decreased (0.887379 --> 0.886995).  Saving model ...
# Epoch 151, Train Loss: 0.8753, Validation Loss: 0.8866
# Validation loss decreased (0.886995 --> 0.886588).  Saving model ...
# Epoch 152, Train Loss: 0.8749, Validation Loss: 0.8862
# Validation loss decreased (0.886588 --> 0.886197).  Saving model ...
# Epoch 153, Train Loss: 0.8744, Validation Loss: 0.8858
# Validation loss decreased (0.886197 --> 0.885816).  Saving model ...
# Epoch 154, Train Loss: 0.8740, Validation Loss: 0.8854
# Validation loss decreased (0.885816 --> 0.885437).  Saving model ...
# Epoch 155, Train Loss: 0.8735, Validation Loss: 0.8851
# Validation loss decreased (0.885437 --> 0.885059).  Saving model ...
# Epoch 156, Train Loss: 0.8731, Validation Loss: 0.8847
# Validation loss decreased (0.885059 --> 0.884687).  Saving model ...
# Epoch 157, Train Loss: 0.8727, Validation Loss: 0.8843
# Validation loss decreased (0.884687 --> 0.884323).  Saving model ...
# Epoch 158, Train Loss: 0.8722, Validation Loss: 0.8840
# Validation loss decreased (0.884323 --> 0.883969).  Saving model ...
# Epoch 159, Train Loss: 0.8718, Validation Loss: 0.8836
# Validation loss decreased (0.883969 --> 0.883600).  Saving model ...
# Epoch 160, Train Loss: 0.8714, Validation Loss: 0.8833
# Validation loss decreased (0.883600 --> 0.883252).  Saving model ...
# Epoch 161, Train Loss: 0.8710, Validation Loss: 0.8829
# Validation loss decreased (0.883252 --> 0.882904).  Saving model ...
# Epoch 162, Train Loss: 0.8706, Validation Loss: 0.8826
# Validation loss decreased (0.882904 --> 0.882552).  Saving model ...
# Epoch 163, Train Loss: 0.8701, Validation Loss: 0.8822
# Validation loss decreased (0.882552 --> 0.882198).  Saving model ...
# Epoch 164, Train Loss: 0.8697, Validation Loss: 0.8819
# Validation loss decreased (0.882198 --> 0.881864).  Saving model ...
# Epoch 165, Train Loss: 0.8693, Validation Loss: 0.8815
# Validation loss decreased (0.881864 --> 0.881527).  Saving model ...
# Epoch 166, Train Loss: 0.8689, Validation Loss: 0.8812
# Validation loss decreased (0.881527 --> 0.881186).  Saving model ...
# Epoch 167, Train Loss: 0.8685, Validation Loss: 0.8809
# Validation loss decreased (0.881186 --> 0.880854).  Saving model ...
# Epoch 168, Train Loss: 0.8682, Validation Loss: 0.8805
# Validation loss decreased (0.880854 --> 0.880523).  Saving model ...
# Epoch 169, Train Loss: 0.8678, Validation Loss: 0.8802
# Validation loss decreased (0.880523 --> 0.880194).  Saving model ...
# Epoch 170, Train Loss: 0.8674, Validation Loss: 0.8799
# Validation loss decreased (0.880194 --> 0.879869).  Saving model ...
# Epoch 171, Train Loss: 0.8670, Validation Loss: 0.8796
# Validation loss decreased (0.879869 --> 0.879553).  Saving model ...
# Epoch 172, Train Loss: 0.8666, Validation Loss: 0.8792
# Validation loss decreased (0.879553 --> 0.879232).  Saving model ...
# Epoch 173, Train Loss: 0.8662, Validation Loss: 0.8789
# Validation loss decreased (0.879232 --> 0.878916).  Saving model ...
# Epoch 174, Train Loss: 0.8659, Validation Loss: 0.8786
# Validation loss decreased (0.878916 --> 0.878601).  Saving model ...
# Epoch 175, Train Loss: 0.8655, Validation Loss: 0.8783
# Validation loss decreased (0.878601 --> 0.878277).  Saving model ...
# Epoch 176, Train Loss: 0.8651, Validation Loss: 0.8780
# Validation loss decreased (0.878277 --> 0.877964).  Saving model ...
# Epoch 177, Train Loss: 0.8647, Validation Loss: 0.8776
# Validation loss decreased (0.877964 --> 0.877645).  Saving model ...
# Epoch 178, Train Loss: 0.8644, Validation Loss: 0.8773
# Validation loss decreased (0.877645 --> 0.877333).  Saving model ...
# Epoch 179, Train Loss: 0.8640, Validation Loss: 0.8770
# Validation loss decreased (0.877333 --> 0.877025).  Saving model ...
# Epoch 180, Train Loss: 0.8636, Validation Loss: 0.8767
# Validation loss decreased (0.877025 --> 0.876712).  Saving model ...
# Epoch 181, Train Loss: 0.8633, Validation Loss: 0.8764
# Validation loss decreased (0.876712 --> 0.876397).  Saving model ...
# Epoch 182, Train Loss: 0.8629, Validation Loss: 0.8761
# Validation loss decreased (0.876397 --> 0.876093).  Saving model ...
# Epoch 183, Train Loss: 0.8625, Validation Loss: 0.8758
# Validation loss decreased (0.876093 --> 0.875788).  Saving model ...
# Epoch 184, Train Loss: 0.8622, Validation Loss: 0.8755
# Validation loss decreased (0.875788 --> 0.875475).  Saving model ...
# Epoch 185, Train Loss: 0.8618, Validation Loss: 0.8752
# Validation loss decreased (0.875475 --> 0.875172).  Saving model ...
# Epoch 186, Train Loss: 0.8614, Validation Loss: 0.8749
# Validation loss decreased (0.875172 --> 0.874864).  Saving model ...
# Epoch 187, Train Loss: 0.8611, Validation Loss: 0.8746
# Validation loss decreased (0.874864 --> 0.874556).  Saving model ...
# Epoch 188, Train Loss: 0.8607, Validation Loss: 0.8743
# Validation loss decreased (0.874556 --> 0.874260).  Saving model ...
# Epoch 189, Train Loss: 0.8603, Validation Loss: 0.8740
# Validation loss decreased (0.874260 --> 0.873956).  Saving model ...
# Epoch 190, Train Loss: 0.8600, Validation Loss: 0.8737
# Validation loss decreased (0.873956 --> 0.873651).  Saving model ...
# Epoch 191, Train Loss: 0.8596, Validation Loss: 0.8733
# Validation loss decreased (0.873651 --> 0.873345).  Saving model ...
# Epoch 192, Train Loss: 0.8593, Validation Loss: 0.8730
# Validation loss decreased (0.873345 --> 0.873038).  Saving model ...
# Epoch 193, Train Loss: 0.8589, Validation Loss: 0.8727
# Validation loss decreased (0.873038 --> 0.872741).  Saving model ...
# Epoch 194, Train Loss: 0.8586, Validation Loss: 0.8724
# Validation loss decreased (0.872741 --> 0.872436).  Saving model ...
# Epoch 195, Train Loss: 0.8582, Validation Loss: 0.8721
# Validation loss decreased (0.872436 --> 0.872134).  Saving model ...
# Epoch 196, Train Loss: 0.8579, Validation Loss: 0.8718
# Validation loss decreased (0.872134 --> 0.871836).  Saving model ...
# Epoch 197, Train Loss: 0.8575, Validation Loss: 0.8715
# Validation loss decreased (0.871836 --> 0.871527).  Saving model ...
# Epoch 198, Train Loss: 0.8571, Validation Loss: 0.8712
# Validation loss decreased (0.871527 --> 0.871218).  Saving model ...
# Epoch 199, Train Loss: 0.8568, Validation Loss: 0.8709
# Validation loss decreased (0.871218 --> 0.870914).  Saving model ...
# Epoch 200, Train Loss: 0.8564, Validation Loss: 0.8706
# Validation loss decreased (0.870914 --> 0.870616).  Saving model ...
# Epoch 201, Train Loss: 0.8561, Validation Loss: 0.8703
# Validation loss decreased (0.870616 --> 0.870317).  Saving model ...
# Epoch 202, Train Loss: 0.8557, Validation Loss: 0.8700
# Validation loss decreased (0.870317 --> 0.870009).  Saving model ...
# Epoch 203, Train Loss: 0.8554, Validation Loss: 0.8697
# Validation loss decreased (0.870009 --> 0.869703).  Saving model ...
# Epoch 204, Train Loss: 0.8550, Validation Loss: 0.8694
# Validation loss decreased (0.869703 --> 0.869402).  Saving model ...
# Epoch 205, Train Loss: 0.8547, Validation Loss: 0.8691
# Validation loss decreased (0.869402 --> 0.869103).  Saving model ...
# Epoch 206, Train Loss: 0.8543, Validation Loss: 0.8688
# Validation loss decreased (0.869103 --> 0.868787).  Saving model ...
# Epoch 207, Train Loss: 0.8540, Validation Loss: 0.8685
# Validation loss decreased (0.868787 --> 0.868484).  Saving model ...
# Epoch 208, Train Loss: 0.8536, Validation Loss: 0.8682
# Validation loss decreased (0.868484 --> 0.868180).  Saving model ...
# Epoch 209, Train Loss: 0.8532, Validation Loss: 0.8679
# Validation loss decreased (0.868180 --> 0.867866).  Saving model ...
# Epoch 210, Train Loss: 0.8529, Validation Loss: 0.8676
# Validation loss decreased (0.867866 --> 0.867561).  Saving model ...
# Epoch 211, Train Loss: 0.8525, Validation Loss: 0.8673
# Validation loss decreased (0.867561 --> 0.867258).  Saving model ...
# Epoch 212, Train Loss: 0.8522, Validation Loss: 0.8670
# Validation loss decreased (0.867258 --> 0.866951).  Saving model ...
# Epoch 213, Train Loss: 0.8518, Validation Loss: 0.8666
# Validation loss decreased (0.866951 --> 0.866632).  Saving model ...
# Epoch 214, Train Loss: 0.8515, Validation Loss: 0.8663
# Validation loss decreased (0.866632 --> 0.866320).  Saving model ...
# Epoch 215, Train Loss: 0.8511, Validation Loss: 0.8660
# Validation loss decreased (0.866320 --> 0.866013).  Saving model ...
# Epoch 216, Train Loss: 0.8507, Validation Loss: 0.8657
# Validation loss decreased (0.866013 --> 0.865701).  Saving model ...
# Epoch 217, Train Loss: 0.8504, Validation Loss: 0.8654
# Validation loss decreased (0.865701 --> 0.865381).  Saving model ...
# Epoch 218, Train Loss: 0.8500, Validation Loss: 0.8651
# Validation loss decreased (0.865381 --> 0.865066).  Saving model ...
# Epoch 219, Train Loss: 0.8497, Validation Loss: 0.8648
# Validation loss decreased (0.865066 --> 0.864750).  Saving model ...
# Epoch 220, Train Loss: 0.8493, Validation Loss: 0.8644
# Validation loss decreased (0.864750 --> 0.864429).  Saving model ...
# Epoch 221, Train Loss: 0.8489, Validation Loss: 0.8641
# Validation loss decreased (0.864429 --> 0.864111).  Saving model ...
# Epoch 222, Train Loss: 0.8486, Validation Loss: 0.8638
# Validation loss decreased (0.864111 --> 0.863791).  Saving model ...
# Epoch 223, Train Loss: 0.8482, Validation Loss: 0.8635
# Validation loss decreased (0.863791 --> 0.863464).  Saving model ...
# Epoch 224, Train Loss: 0.8478, Validation Loss: 0.8631
# Validation loss decreased (0.863464 --> 0.863138).  Saving model ...
# Epoch 225, Train Loss: 0.8475, Validation Loss: 0.8628
# Validation loss decreased (0.863138 --> 0.862808).  Saving model ...
# Epoch 226, Train Loss: 0.8471, Validation Loss: 0.8625
# Validation loss decreased (0.862808 --> 0.862485).  Saving model ...
# Epoch 227, Train Loss: 0.8467, Validation Loss: 0.8621
# Validation loss decreased (0.862485 --> 0.862148).  Saving model ...
# Epoch 228, Train Loss: 0.8463, Validation Loss: 0.8618
# Validation loss decreased (0.862148 --> 0.861809).  Saving model ...
# Epoch 229, Train Loss: 0.8460, Validation Loss: 0.8615
# Validation loss decreased (0.861809 --> 0.861473).  Saving model ...
# Epoch 230, Train Loss: 0.8456, Validation Loss: 0.8611
# Validation loss decreased (0.861473 --> 0.861134).  Saving model ...
# Epoch 231, Train Loss: 0.8452, Validation Loss: 0.8608
# Validation loss decreased (0.861134 --> 0.860793).  Saving model ...
# Epoch 232, Train Loss: 0.8448, Validation Loss: 0.8604
# Validation loss decreased (0.860793 --> 0.860442).  Saving model ...
# Epoch 233, Train Loss: 0.8444, Validation Loss: 0.8601
# Validation loss decreased (0.860442 --> 0.860100).  Saving model ...
# Epoch 234, Train Loss: 0.8440, Validation Loss: 0.8597
# Validation loss decreased (0.860100 --> 0.859743).  Saving model ...
# Epoch 235, Train Loss: 0.8437, Validation Loss: 0.8594
# Validation loss decreased (0.859743 --> 0.859388).  Saving model ...
# Epoch 236, Train Loss: 0.8433, Validation Loss: 0.8590
# Validation loss decreased (0.859388 --> 0.859023).  Saving model ...
# Epoch 237, Train Loss: 0.8429, Validation Loss: 0.8587
# Validation loss decreased (0.859023 --> 0.858655).  Saving model ...
# Epoch 238, Train Loss: 0.8425, Validation Loss: 0.8583
# Validation loss decreased (0.858655 --> 0.858291).  Saving model ...
# Epoch 239, Train Loss: 0.8420, Validation Loss: 0.8579
# Validation loss decreased (0.858291 --> 0.857911).  Saving model ...
# Epoch 240, Train Loss: 0.8416, Validation Loss: 0.8575
# Validation loss decreased (0.857911 --> 0.857527).  Saving model ...
# Epoch 241, Train Loss: 0.8412, Validation Loss: 0.8571
# Validation loss decreased (0.857527 --> 0.857141).  Saving model ...
# Epoch 242, Train Loss: 0.8408, Validation Loss: 0.8568
# Validation loss decreased (0.857141 --> 0.856752).  Saving model ...
# Epoch 243, Train Loss: 0.8404, Validation Loss: 0.8563
# Validation loss decreased (0.856752 --> 0.856350).  Saving model ...
# Epoch 244, Train Loss: 0.8399, Validation Loss: 0.8559
# Validation loss decreased (0.856350 --> 0.855943).  Saving model ...
# Epoch 245, Train Loss: 0.8395, Validation Loss: 0.8555
# Validation loss decreased (0.855943 --> 0.855532).  Saving model ...
# Epoch 246, Train Loss: 0.8391, Validation Loss: 0.8551
# Validation loss decreased (0.855532 --> 0.855115).  Saving model ...
# Epoch 247, Train Loss: 0.8386, Validation Loss: 0.8547
# Validation loss decreased (0.855115 --> 0.854678).  Saving model ...
# Epoch 248, Train Loss: 0.8381, Validation Loss: 0.8542
# Validation loss decreased (0.854678 --> 0.854235).  Saving model ...
# Epoch 249, Train Loss: 0.8377, Validation Loss: 0.8538
# Validation loss decreased (0.854235 --> 0.853780).  Saving model ...
# Epoch 250, Train Loss: 0.8372, Validation Loss: 0.8533
# Validation loss decreased (0.853780 --> 0.853319).  Saving model ...
# Epoch 251, Train Loss: 0.8367, Validation Loss: 0.8528
# Validation loss decreased (0.853319 --> 0.852850).  Saving model ...
# Epoch 252, Train Loss: 0.8362, Validation Loss: 0.8524
# Validation loss decreased (0.852850 --> 0.852356).  Saving model ...
# Epoch 253, Train Loss: 0.8357, Validation Loss: 0.8519
# Validation loss decreased (0.852356 --> 0.851857).  Saving model ...
# Epoch 254, Train Loss: 0.8351, Validation Loss: 0.8513
# Validation loss decreased (0.851857 --> 0.851332).  Saving model ...
# Epoch 255, Train Loss: 0.8346, Validation Loss: 0.8508
# Validation loss decreased (0.851332 --> 0.850796).  Saving model ...
# Epoch 256, Train Loss: 0.8340, Validation Loss: 0.8502
# Validation loss decreased (0.850796 --> 0.850232).  Saving model ...
# Epoch 257, Train Loss: 0.8335, Validation Loss: 0.8497
# Validation loss decreased (0.850232 --> 0.849666).  Saving model ...
# Epoch 258, Train Loss: 0.8329, Validation Loss: 0.8491
# Validation loss decreased (0.849666 --> 0.849066).  Saving model ...
# Epoch 259, Train Loss: 0.8323, Validation Loss: 0.8484
# Validation loss decreased (0.849066 --> 0.848434).  Saving model ...
# Epoch 260, Train Loss: 0.8316, Validation Loss: 0.8478
# Validation loss decreased (0.848434 --> 0.847778).  Saving model ...
# Epoch 261, Train Loss: 0.8309, Validation Loss: 0.8471
# Validation loss decreased (0.847778 --> 0.847090).  Saving model ...
# Epoch 262, Train Loss: 0.8302, Validation Loss: 0.8464
# Validation loss decreased (0.847090 --> 0.846368).  Saving model ...
# Epoch 263, Train Loss: 0.8295, Validation Loss: 0.8456
# Validation loss decreased (0.846368 --> 0.845613).  Saving model ...
# Epoch 264, Train Loss: 0.8288, Validation Loss: 0.8448
# Validation loss decreased (0.845613 --> 0.844822).  Saving model ...
# Epoch 265, Train Loss: 0.8280, Validation Loss: 0.8440
# Validation loss decreased (0.844822 --> 0.843985).  Saving model ...
# Epoch 266, Train Loss: 0.8271, Validation Loss: 0.8431
# Validation loss decreased (0.843985 --> 0.843091).  Saving model ...
# Epoch 267, Train Loss: 0.8262, Validation Loss: 0.8421
# Validation loss decreased (0.843091 --> 0.842150).  Saving model ...
# Epoch 268, Train Loss: 0.8253, Validation Loss: 0.8411
# Validation loss decreased (0.842150 --> 0.841135).  Saving model ...
# Epoch 269, Train Loss: 0.8243, Validation Loss: 0.8401
# Validation loss decreased (0.841135 --> 0.840077).  Saving model ...
# Epoch 270, Train Loss: 0.8232, Validation Loss: 0.8390
# Validation loss decreased (0.840077 --> 0.838951).  Saving model ...
# Epoch 271, Train Loss: 0.8221, Validation Loss: 0.8377
# Validation loss decreased (0.838951 --> 0.837741).  Saving model ...
# Epoch 272, Train Loss: 0.8210, Validation Loss: 0.8365
# Validation loss decreased (0.837741 --> 0.836469).  Saving model ...
# Epoch 273, Train Loss: 0.8197, Validation Loss: 0.8351
# Validation loss decreased (0.836469 --> 0.835111).  Saving model ...
# Epoch 274, Train Loss: 0.8184, Validation Loss: 0.8337
# Validation loss decreased (0.835111 --> 0.833677).  Saving model ...
# Epoch 275, Train Loss: 0.8170, Validation Loss: 0.8322
# Validation loss decreased (0.833677 --> 0.832173).  Saving model ...
# Epoch 276, Train Loss: 0.8155, Validation Loss: 0.8306
# Validation loss decreased (0.832173 --> 0.830561).  Saving model ...
# Epoch 277, Train Loss: 0.8140, Validation Loss: 0.8289
# Validation loss decreased (0.830561 --> 0.828895).  Saving model ...
# Epoch 278, Train Loss: 0.8123, Validation Loss: 0.8271
# Validation loss decreased (0.828895 --> 0.827142).  Saving model ...
# Epoch 279, Train Loss: 0.8106, Validation Loss: 0.8253
# Validation loss decreased (0.827142 --> 0.825318).  Saving model ...
# Epoch 280, Train Loss: 0.8089, Validation Loss: 0.8235
# Validation loss decreased (0.825318 --> 0.823461).  Saving model ...
# Epoch 281, Train Loss: 0.8071, Validation Loss: 0.8216
# Validation loss decreased (0.823461 --> 0.821597).  Saving model ...
# Epoch 282, Train Loss: 0.8054, Validation Loss: 0.8197
# Validation loss decreased (0.821597 --> 0.819700).  Saving model ...
# Epoch 283, Train Loss: 0.8036, Validation Loss: 0.8178
# Validation loss decreased (0.819700 --> 0.817836).  Saving model ...
# Epoch 284, Train Loss: 0.8018, Validation Loss: 0.8160
# Validation loss decreased (0.817836 --> 0.815991).  Saving model ...
# Epoch 285, Train Loss: 0.8001, Validation Loss: 0.8142
# Validation loss decreased (0.815991 --> 0.814221).  Saving model ...
# Epoch 286, Train Loss: 0.7985, Validation Loss: 0.8125
# Validation loss decreased (0.814221 --> 0.812530).  Saving model ...
# Epoch 287, Train Loss: 0.7969, Validation Loss: 0.8109
# Validation loss decreased (0.812530 --> 0.810923).  Saving model ...
# Epoch 288, Train Loss: 0.7954, Validation Loss: 0.8094
# Validation loss decreased (0.810923 --> 0.809429).  Saving model ...
# Epoch 289, Train Loss: 0.7940, Validation Loss: 0.8080
# Validation loss decreased (0.809429 --> 0.808038).  Saving model ...
# Epoch 290, Train Loss: 0.7928, Validation Loss: 0.8068
# Validation loss decreased (0.808038 --> 0.806773).  Saving model ...
# Epoch 291, Train Loss: 0.7916, Validation Loss: 0.8056
# Validation loss decreased (0.806773 --> 0.805588).  Saving model ...
# Epoch 292, Train Loss: 0.7905, Validation Loss: 0.8045
# Validation loss decreased (0.805588 --> 0.804501).  Saving model ...
# Epoch 293, Train Loss: 0.7896, Validation Loss: 0.8035
# Validation loss decreased (0.804501 --> 0.803500).  Saving model ...
# Epoch 294, Train Loss: 0.7886, Validation Loss: 0.8026
# Validation loss decreased (0.803500 --> 0.802567).  Saving model ...
# Epoch 295, Train Loss: 0.7878, Validation Loss: 0.8017
# Validation loss decreased (0.802567 --> 0.801719).  Saving model ...
# Epoch 296, Train Loss: 0.7870, Validation Loss: 0.8009
# Validation loss decreased (0.801719 --> 0.800907).  Saving model ...
# Epoch 297, Train Loss: 0.7863, Validation Loss: 0.8002
# Validation loss decreased (0.800907 --> 0.800151).  Saving model ...
# Epoch 298, Train Loss: 0.7856, Validation Loss: 0.7994
# Validation loss decreased (0.800151 --> 0.799432).  Saving model ...
# Epoch 299, Train Loss: 0.7849, Validation Loss: 0.7988
# Validation loss decreased (0.799432 --> 0.798756).  Saving model ...
# Epoch 300, Train Loss: 0.7842, Validation Loss: 0.7981
# Validation loss decreased (0.798756 --> 0.798110).  Saving model ...
# Epoch 301, Train Loss: 0.7836, Validation Loss: 0.7975
# Validation loss decreased (0.798110 --> 0.797488).  Saving model ...
# Epoch 302, Train Loss: 0.7830, Validation Loss: 0.7969
# Validation loss decreased (0.797488 --> 0.796894).  Saving model ...
# Epoch 303, Train Loss: 0.7825, Validation Loss: 0.7963
# Validation loss decreased (0.796894 --> 0.796313).  Saving model ...
# Epoch 304, Train Loss: 0.7819, Validation Loss: 0.7957
# Validation loss decreased (0.796313 --> 0.795743).  Saving model ...
# Epoch 305, Train Loss: 0.7814, Validation Loss: 0.7952
# Validation loss decreased (0.795743 --> 0.795211).  Saving model ...
# Epoch 306, Train Loss: 0.7808, Validation Loss: 0.7947
# Validation loss decreased (0.795211 --> 0.794678).  Saving model ...
# Epoch 307, Train Loss: 0.7803, Validation Loss: 0.7942
# Validation loss decreased (0.794678 --> 0.794167).  Saving model ...
# Epoch 308, Train Loss: 0.7798, Validation Loss: 0.7937
# Validation loss decreased (0.794167 --> 0.793670).  Saving model ...
# Epoch 309, Train Loss: 0.7793, Validation Loss: 0.7932
# Validation loss decreased (0.793670 --> 0.793180).  Saving model ...
# Epoch 310, Train Loss: 0.7788, Validation Loss: 0.7927
# Validation loss decreased (0.793180 --> 0.792707).  Saving model ...
# Epoch 311, Train Loss: 0.7784, Validation Loss: 0.7923
# Validation loss decreased (0.792707 --> 0.792255).  Saving model ...
# Epoch 312, Train Loss: 0.7779, Validation Loss: 0.7918
# Validation loss decreased (0.792255 --> 0.791788).  Saving model ...
# Epoch 313, Train Loss: 0.7775, Validation Loss: 0.7913
# Validation loss decreased (0.791788 --> 0.791341).  Saving model ...
# Epoch 314, Train Loss: 0.7770, Validation Loss: 0.7909
# Validation loss decreased (0.791341 --> 0.790906).  Saving model ...
# Epoch 315, Train Loss: 0.7766, Validation Loss: 0.7905
# Validation loss decreased (0.790906 --> 0.790474).  Saving model ...
# Epoch 316, Train Loss: 0.7761, Validation Loss: 0.7901
# Validation loss decreased (0.790474 --> 0.790068).  Saving model ...
# Epoch 317, Train Loss: 0.7757, Validation Loss: 0.7896
# Validation loss decreased (0.790068 --> 0.789633).  Saving model ...
# Epoch 318, Train Loss: 0.7753, Validation Loss: 0.7892
# Validation loss decreased (0.789633 --> 0.789209).  Saving model ...
# Epoch 319, Train Loss: 0.7748, Validation Loss: 0.7888
# Validation loss decreased (0.789209 --> 0.788798).  Saving model ...
# Epoch 320, Train Loss: 0.7744, Validation Loss: 0.7884
# Validation loss decreased (0.788798 --> 0.788395).  Saving model ...
# Epoch 321, Train Loss: 0.7740, Validation Loss: 0.7880
# Validation loss decreased (0.788395 --> 0.787998).  Saving model ...
# Epoch 322, Train Loss: 0.7736, Validation Loss: 0.7876
# Validation loss decreased (0.787998 --> 0.787599).  Saving model ...
# Epoch 323, Train Loss: 0.7732, Validation Loss: 0.7872
# Validation loss decreased (0.787599 --> 0.787203).  Saving model ...
# Epoch 324, Train Loss: 0.7728, Validation Loss: 0.7868
# Validation loss decreased (0.787203 --> 0.786817).  Saving model ...
# Epoch 325, Train Loss: 0.7724, Validation Loss: 0.7864
# Validation loss decreased (0.786817 --> 0.786429).  Saving model ...
# Epoch 326, Train Loss: 0.7720, Validation Loss: 0.7861
# Validation loss decreased (0.786429 --> 0.786051).  Saving model ...
# Epoch 327, Train Loss: 0.7716, Validation Loss: 0.7857
# Validation loss decreased (0.786051 --> 0.785670).  Saving model ...
# Epoch 328, Train Loss: 0.7712, Validation Loss: 0.7853
# Validation loss decreased (0.785670 --> 0.785290).  Saving model ...
# Epoch 329, Train Loss: 0.7708, Validation Loss: 0.7849
# Validation loss decreased (0.785290 --> 0.784919).  Saving model ...
# Epoch 330, Train Loss: 0.7704, Validation Loss: 0.7846
# Validation loss decreased (0.784919 --> 0.784550).  Saving model ...
# Epoch 331, Train Loss: 0.7701, Validation Loss: 0.7842
# Validation loss decreased (0.784550 --> 0.784175).  Saving model ...
# Epoch 332, Train Loss: 0.7697, Validation Loss: 0.7838
# Validation loss decreased (0.784175 --> 0.783817).  Saving model ...
# Epoch 333, Train Loss: 0.7693, Validation Loss: 0.7835
# Validation loss decreased (0.783817 --> 0.783464).  Saving model ...
# Epoch 334, Train Loss: 0.7689, Validation Loss: 0.7831
# Validation loss decreased (0.783464 --> 0.783099).  Saving model ...
# Epoch 335, Train Loss: 0.7686, Validation Loss: 0.7827
# Validation loss decreased (0.783099 --> 0.782734).  Saving model ...
# Epoch 336, Train Loss: 0.7682, Validation Loss: 0.7824
# Validation loss decreased (0.782734 --> 0.782365).  Saving model ...
# Epoch 337, Train Loss: 0.7678, Validation Loss: 0.7820
# Validation loss decreased (0.782365 --> 0.782019).  Saving model ...
# Epoch 338, Train Loss: 0.7675, Validation Loss: 0.7817
# Validation loss decreased (0.782019 --> 0.781668).  Saving model ...
# Epoch 339, Train Loss: 0.7671, Validation Loss: 0.7813
# Validation loss decreased (0.781668 --> 0.781316).  Saving model ...
# Epoch 340, Train Loss: 0.7667, Validation Loss: 0.7810
# Validation loss decreased (0.781316 --> 0.780970).  Saving model ...
# Epoch 341, Train Loss: 0.7664, Validation Loss: 0.7806
# Validation loss decreased (0.780970 --> 0.780636).  Saving model ...
# Epoch 342, Train Loss: 0.7660, Validation Loss: 0.7803
# Validation loss decreased (0.780636 --> 0.780285).  Saving model ...
# Epoch 343, Train Loss: 0.7656, Validation Loss: 0.7799
# Validation loss decreased (0.780285 --> 0.779917).  Saving model ...
# Epoch 344, Train Loss: 0.7653, Validation Loss: 0.7796
# Validation loss decreased (0.779917 --> 0.779588).  Saving model ...
# Epoch 345, Train Loss: 0.7649, Validation Loss: 0.7792
# Validation loss decreased (0.779588 --> 0.779245).  Saving model ...
# Epoch 346, Train Loss: 0.7646, Validation Loss: 0.7789
# Validation loss decreased (0.779245 --> 0.778900).  Saving model ...
# Epoch 347, Train Loss: 0.7642, Validation Loss: 0.7786
# Validation loss decreased (0.778900 --> 0.778565).  Saving model ...
# Epoch 348, Train Loss: 0.7639, Validation Loss: 0.7782
# Validation loss decreased (0.778565 --> 0.778222).  Saving model ...
# Epoch 349, Train Loss: 0.7635, Validation Loss: 0.7779
# Validation loss decreased (0.778222 --> 0.777897).  Saving model ...
# Epoch 350, Train Loss: 0.7632, Validation Loss: 0.7776
# Validation loss decreased (0.777897 --> 0.777556).  Saving model ...
# Epoch 351, Train Loss: 0.7628, Validation Loss: 0.7772
# Validation loss decreased (0.777556 --> 0.777228).  Saving model ...
# Epoch 352, Train Loss: 0.7625, Validation Loss: 0.7769
# Validation loss decreased (0.777228 --> 0.776900).  Saving model ...
# Epoch 353, Train Loss: 0.7622, Validation Loss: 0.7766
# Validation loss decreased (0.776900 --> 0.776555).  Saving model ...
# Epoch 354, Train Loss: 0.7618, Validation Loss: 0.7762
# Validation loss decreased (0.776555 --> 0.776234).  Saving model ...
# Epoch 355, Train Loss: 0.7615, Validation Loss: 0.7759
# Validation loss decreased (0.776234 --> 0.775905).  Saving model ...
# Epoch 356, Train Loss: 0.7611, Validation Loss: 0.7756
# Validation loss decreased (0.775905 --> 0.775578).  Saving model ...
# Epoch 357, Train Loss: 0.7608, Validation Loss: 0.7752
# Validation loss decreased (0.775578 --> 0.775241).  Saving model ...
# Epoch 358, Train Loss: 0.7605, Validation Loss: 0.7749
# Validation loss decreased (0.775241 --> 0.774920).  Saving model ...
# Epoch 359, Train Loss: 0.7601, Validation Loss: 0.7746
# Validation loss decreased (0.774920 --> 0.774598).  Saving model ...
# Epoch 360, Train Loss: 0.7598, Validation Loss: 0.7743
# Validation loss decreased (0.774598 --> 0.774266).  Saving model ...
# Epoch 361, Train Loss: 0.7595, Validation Loss: 0.7739
# Validation loss decreased (0.774266 --> 0.773948).  Saving model ...
# Epoch 362, Train Loss: 0.7591, Validation Loss: 0.7736
# Validation loss decreased (0.773948 --> 0.773637).  Saving model ...
# Epoch 363, Train Loss: 0.7588, Validation Loss: 0.7733
# Validation loss decreased (0.773637 --> 0.773319).  Saving model ...
# Epoch 364, Train Loss: 0.7585, Validation Loss: 0.7730
# Validation loss decreased (0.773319 --> 0.772982).  Saving model ...
# Epoch 365, Train Loss: 0.7581, Validation Loss: 0.7727
# Validation loss decreased (0.772982 --> 0.772657).  Saving model ...
# Epoch 366, Train Loss: 0.7578, Validation Loss: 0.7723
# Validation loss decreased (0.772657 --> 0.772338).  Saving model ...
# Epoch 367, Train Loss: 0.7575, Validation Loss: 0.7720
# Validation loss decreased (0.772338 --> 0.772021).  Saving model ...
# Epoch 368, Train Loss: 0.7571, Validation Loss: 0.7717
# Validation loss decreased (0.772021 --> 0.771706).  Saving model ...
# Epoch 369, Train Loss: 0.7568, Validation Loss: 0.7714
# Validation loss decreased (0.771706 --> 0.771380).  Saving model ...
# Epoch 370, Train Loss: 0.7565, Validation Loss: 0.7711
# Validation loss decreased (0.771380 --> 0.771073).  Saving model ...
# Epoch 371, Train Loss: 0.7562, Validation Loss: 0.7707
# Validation loss decreased (0.771073 --> 0.770744).  Saving model ...
# Epoch 372, Train Loss: 0.7558, Validation Loss: 0.7704
# Validation loss decreased (0.770744 --> 0.770434).  Saving model ...
# Epoch 373, Train Loss: 0.7555, Validation Loss: 0.7701
# Validation loss decreased (0.770434 --> 0.770122).  Saving model ...
# Epoch 374, Train Loss: 0.7552, Validation Loss: 0.7698
# Validation loss decreased (0.770122 --> 0.769804).  Saving model ...
# Epoch 375, Train Loss: 0.7549, Validation Loss: 0.7695
# Validation loss decreased (0.769804 --> 0.769483).  Saving model ...
# Epoch 376, Train Loss: 0.7545, Validation Loss: 0.7692
# Validation loss decreased (0.769483 --> 0.769176).  Saving model ...
# Epoch 377, Train Loss: 0.7542, Validation Loss: 0.7689
# Validation loss decreased (0.769176 --> 0.768850).  Saving model ...
# Epoch 378, Train Loss: 0.7539, Validation Loss: 0.7685
# Validation loss decreased (0.768850 --> 0.768526).  Saving model ...
# Epoch 379, Train Loss: 0.7536, Validation Loss: 0.7682
# Validation loss decreased (0.768526 --> 0.768216).  Saving model ...
# Epoch 380, Train Loss: 0.7532, Validation Loss: 0.7679
# Validation loss decreased (0.768216 --> 0.767903).  Saving model ...
# Epoch 381, Train Loss: 0.7529, Validation Loss: 0.7676
# Validation loss decreased (0.767903 --> 0.767591).  Saving model ...
# Epoch 382, Train Loss: 0.7526, Validation Loss: 0.7673
# Validation loss decreased (0.767591 --> 0.767285).  Saving model ...
# Epoch 383, Train Loss: 0.7523, Validation Loss: 0.7670
# Validation loss decreased (0.767285 --> 0.766964).  Saving model ...
# Epoch 384, Train Loss: 0.7520, Validation Loss: 0.7667
# Validation loss decreased (0.766964 --> 0.766662).  Saving model ...
# Epoch 385, Train Loss: 0.7516, Validation Loss: 0.7663
# Validation loss decreased (0.766662 --> 0.766340).  Saving model ...
# Epoch 386, Train Loss: 0.7513, Validation Loss: 0.7660
# Validation loss decreased (0.766340 --> 0.766034).  Saving model ...
# Epoch 387, Train Loss: 0.7510, Validation Loss: 0.7657
# Validation loss decreased (0.766034 --> 0.765726).  Saving model ...
# Epoch 388, Train Loss: 0.7507, Validation Loss: 0.7654
# Validation loss decreased (0.765726 --> 0.765408).  Saving model ...
# Epoch 389, Train Loss: 0.7504, Validation Loss: 0.7651
# Validation loss decreased (0.765408 --> 0.765097).  Saving model ...
# Epoch 390, Train Loss: 0.7501, Validation Loss: 0.7648
# Validation loss decreased (0.765097 --> 0.764781).  Saving model ...
# Epoch 391, Train Loss: 0.7497, Validation Loss: 0.7645
# Validation loss decreased (0.764781 --> 0.764467).  Saving model ...
# Epoch 392, Train Loss: 0.7494, Validation Loss: 0.7642
# Validation loss decreased (0.764467 --> 0.764154).  Saving model ...
# Epoch 393, Train Loss: 0.7491, Validation Loss: 0.7638
# Validation loss decreased (0.764154 --> 0.763838).  Saving model ...
# Epoch 394, Train Loss: 0.7488, Validation Loss: 0.7635
# Validation loss decreased (0.763838 --> 0.763538).  Saving model ...
# Epoch 395, Train Loss: 0.7485, Validation Loss: 0.7632
# Validation loss decreased (0.763538 --> 0.763225).  Saving model ...
# Epoch 396, Train Loss: 0.7481, Validation Loss: 0.7629
# Validation loss decreased (0.763225 --> 0.762932).  Saving model ...
# Epoch 397, Train Loss: 0.7478, Validation Loss: 0.7626
# Validation loss decreased (0.762932 --> 0.762603).  Saving model ...
# Epoch 398, Train Loss: 0.7475, Validation Loss: 0.7623
# Validation loss decreased (0.762603 --> 0.762292).  Saving model ...
# Epoch 399, Train Loss: 0.7472, Validation Loss: 0.7620
# Validation loss decreased (0.762292 --> 0.761978).  Saving model ...
# Epoch 400, Train Loss: 0.7469, Validation Loss: 0.7617
# Validation loss decreased (0.761978 --> 0.761674).  Saving model ...

# %%
# Loss visualization
plt.figure(figsize=(10, 5))
plt.plot(loss_, label='Train Loss')
plt.plot(valoss_, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### 모델 불러오기

# %%
model.load_state_dict(torch.load('ARL1_L3_025.pt', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %% [markdown]
# #### 학습 데이터로부터  잠재 벡터 추출

# %%
latent_vectors = []
model.eval()
with torch.no_grad():
    for data in trainloader:
        inputs = data.to(device)
        latent_vec, _ = model.encoder(inputs)
        latent_vectors.append(latent_vec.cpu().numpy())
latent_vectors = np.concatenate(latent_vectors, axis=0)
latent_vectors
# Out:
# array([[ 0.598887  ,  0.6886355 , -0.49275357],
#        [-0.03903681, -0.02044805, -0.07634261],
#        [-0.03485159,  0.01170043,  0.04996924],
#        ...,
#        [ 0.4473879 ,  0.35337982,  0.28674433],
#        [ 0.25238922,  0.2528871 , -0.51702577],
#        [ 0.42857367,  0.14993869,  0.00247745]], dtype=float32)

# %%
import seaborn as sns

# 박스플롯 및 바이올린 플롯 그리기
plt.figure(figsize=(14, 6))

# 박스플롯
plt.subplot(1, 2, 1)
plt.boxplot(latent_vectors, vert=True, patch_artist=True)
plt.xlabel('Latent Vector Dimensions')
plt.ylabel('Values')
plt.title('Boxplot of Latent Vectors')
plt.grid(True)

# 바이올린 플롯
plt.subplot(1, 2, 2)
sns.violinplot(data=latent_vectors, orient='v')
plt.xlabel('Latent Vector Dimensions')
plt.ylabel('Values')
plt.title('Violin Plot of Latent Vectors')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
def mahalanobis_distance(latent_vectors):
    # 평균 벡터 계산
    mean_vector = np.mean(latent_vectors, axis=0)
    
    # v_i 벡터 계산 (px1벡터)
    v = latent_vectors[1:] - latent_vectors[:-1]
    
    # 공분산 행렬 계산
    vvT = np.dot(v.T, v)
    cov_matrix = (1 / 2) * (vvT / (latent_vectors.shape[0] - 1))
    
    # 공분산 행렬의 역행렬 계산
    inv_cov_matrix = np.linalg.inv(cov_matrix)
    
    # Mahalanobis 거리 계산 함수
    def calculate_distance(vector):
        diff = vector - mean_vector
        dist = np.sqrt(np.dot(np.dot(diff.T, inv_cov_matrix), diff))
        return dist
    
    # 각 벡터에 대해 Mahalanobis 거리 계산
    distances = np.apply_along_axis(calculate_distance, 1, latent_vectors)
    
    return distances

# latent_vectors 배열에 대해 Mahalanobis 거리 계산
distances = mahalanobis_distance(latent_vectors)
distances
# Out:
# array([3.0166473 , 0.93260396, 1.2694207 , ..., 2.1954205 , 1.6140621 ,
#        1.1400193 ], dtype=float32)

# %%
plt.figure(figsize=(10,6))
plt.plot(distances, 'o-', markersize=3)
plt.xlabel('Sample Index')
plt.ylabel('Latent Vector Value')
plt.title('Latent Vectors from Training Data')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 다변량 정규성 검정

# %%
import pandas as pd
import pingouin as pg

# latent_vectors를 DataFrame으로 변환 (pingouin 사용을 위해)
df = pd.DataFrame(latent_vectors)

# Mardia's Test 수행
mardia_test = pg.multivariate_normality(df, alpha = 0.05)

# mardia_test는 튜플로 반환됩니다.
hz_stat, p_value, normal = mardia_test

# 결과 출력 및 해석
print("Mardia's Test 결과:")
print(f"Test Statistic (HZ): {hz_stat}")
print(f"p-value: {p_value}")

if normal:
    print("데이터는 다변량 정규성을 따릅니다.")
else:
    print("데이터는 다변량 정규성을 따르지 않습니다.")
# Out:
# Mardia's Test 결과:
# Test Statistic (HZ): 9.610919922056121
# p-value: 2.222504941838604e-78
# 데이터는 다변량 정규성을 따르지 않습니다.

# %% [markdown]
# #### ARL0 구하기

# %%
np.random.seed(1)

l = 12

# 관리상태 / 이상상태 데이터 생성 함수
def argen(ar, delta, gamma, length):

    e = np.random.normal(loc=0, scale = 1,size = length)
    sigma = math.sqrt(1 / (1 - pow(ar, 2)))
    x = np.array(np.repeat(0, length), dtype= np.float64)
    x[0] = e[0]
    z = np.array(np.repeat(0, length), dtype=np.float64)

    for i in range(0,len(x)):
        x[i] = ar * x[i - 1] + gamma*e[i]
        z[i] = x[i]
    for i in range(0,len(z)):
        z[i] = z[i] + delta * sigma

    return z

# %%
# 관리 상태에서 공분산 행렬과 평균 벡터 계산
def calculate_cov_mean(ar, run, length):
    l = 12
    delta = 0
    gamma = 1
    for i in tqdm(range(run)):
        y = argen(ar=ar, delta=delta, gamma=gamma, length=length)
        x = np.zeros(shape=(length - l, l))
        for j in range(length - l):
            x[j] = y[j: j + l]
        x = torch.FloatTensor(x).to(device)
        
        latent_vectors = []
        model.eval()
        with torch.no_grad():
            for j in range(0, len(x)):
                input = x[[j]]
                latent_vec, _ = model.encoder(input)
                latent_vec_value = latent_vec.cpu().numpy()[0]
                latent_vectors.append(latent_vec_value)
        latent_vectors = np.array(latent_vectors)

    mean_vector = np.mean(latent_vectors, axis=0)
    v = latent_vectors[1:] - latent_vectors[:-1]
    vvT = np.dot(v.T, v)
    cov_matrix = (1 / 2) * (vvT / (latent_vectors.shape[0] - 1))
    inv_cov_matrix = np.linalg.inv(cov_matrix)
        
    return latent_vectors, mean_vector, cov_matrix, inv_cov_matrix

# %%
def arl_moving_window(ar, delta, gamma, run, mean_vector, inv_cov_matrix, cl):
    rl = []
    l = 12
    for i in tqdm(range(run)):
        # 초기 데이터 생성
        y = argen(ar=ar, delta=delta, gamma=gamma, length=12)
        
        # 이동 윈도우 방식으로 ARL 계산
        a = 0
        model.eval()
        
        j = 1
        with torch.no_grad():
            while True:
                # 새 데이터 포인트 생성 및 윈도우에 추가
                new_point = argen(ar=ar, delta=delta, gamma=gamma, length=1)
                y = np.append(y[1:], new_point)
                
                # 현재 윈도우의 데이터
                x = torch.FloatTensor([y]).to(device)
                
                # Latent vector 추출
                latent_vec, _ = model.encoder(x)
                latent_vec_value = latent_vec.cpu().numpy()[0]
                
                # Mahalanobis 거리 계산
                diff = latent_vec_value - mean_vector
                mahalanobis_dist = np.sqrt(np.dot(np.dot(diff.T, inv_cov_matrix), diff))
                
                # 탐지 여부 확인
                if mahalanobis_dist > cl:
                    a = j + 1
                    break

                j += 1
                
            rl.append(a)
        
        arl = np.mean(rl)
        
    return arl, rl

# %%
def arl(ar, delta, gamma, run, mean_vector, inv_cov_matrix, cl):
    rl = []
    l = 12
    for i in tqdm(range(run)):
        # 초기 데이터 생성
        y = argen(ar=ar, delta=delta, gamma=gamma, length=12)
        
        # 이동 윈도우 방식으로 ARL 계산
        a = 0
        model.eval()
        
        j = 1
        with torch.no_grad():
            while True:
                # 새 데이터 포인트 생성 및 윈도우에 추가
                new_point = argen(ar=ar, delta=delta, gamma=gamma, length=1)
                y = np.append(y[1:], new_point)
                
                # 현재 윈도우의 데이터
                x = torch.FloatTensor([y]).to(device)
                
                # Latent vector 추출
                latent_vec, _ = model.encoder(x)
                latent_vec_value = latent_vec.cpu().numpy()[0]
                
                # Mahalanobis 거리 계산
                diff = latent_vec_value - mean_vector
                mahalanobis_dist = np.sqrt(np.dot(np.dot(diff.T, inv_cov_matrix), diff))
                
                # 탐지 여부 확인
                if mahalanobis_dist > cl:
                    a = j + 1
                    break

                j += 1
                
            rl.append(a)
        
        arl = np.mean(rl)
        
    return arl

# %% [markdown]
# #### ARL1 구하기

# %%
def arl1(ar, run, mean_vector, inv_cov_matrix, cl):
    a5 = arl(ar, 0.5, 1, run, mean_vector, inv_cov_matrix, cl)
    a1 = arl(ar, 1, 1, run, mean_vector, inv_cov_matrix, cl)
    a2 = arl(ar, 2, 1, run, mean_vector, inv_cov_matrix, cl)
    a3 = arl(ar, 3, 1, run, mean_vector, inv_cov_matrix, cl)
    b5 = arl(ar, 0.5, 1.5, run, mean_vector, inv_cov_matrix, cl)
    b1 = arl(ar, 1, 1.5, run, mean_vector, inv_cov_matrix, cl)
    b2 = arl(ar, 2, 1.5, run, mean_vector, inv_cov_matrix, cl)
    b3 = arl(ar, 3, 1, run, mean_vector, inv_cov_matrix, cl)
    c1 = arl(ar, 0, 1.5, run, mean_vector, inv_cov_matrix, cl)
    c2 = arl(ar, 0, 2, run, mean_vector, inv_cov_matrix, cl)
    c3 = arl(ar, 0, 3, run, mean_vector, inv_cov_matrix, cl)
    print(f'0.5: {a5}, 1:{a1},2:{a2},3:{a3}')
    print(f'0.5:{b5},1:{b1},2:{b2},3:{b3}')
    print(f'1.5:{c1},2:{c2},3:{c3}')

# %% [markdown]
# #### phi = 0.25일 때

# %% [markdown]
# ##### ARL0 (threshold 임의추정)

# %%
# 관리 상태에서 잠재벡터, 평균벡터, 공분산 계산
latent_vectors025, mean_vector025, cov_matrix025, inv_cov_matrix025 = calculate_cov_mean(ar = 0.25, run = 10000, length = 1000)
# Out:
# 100%|██████████| 10000/10000 [20:20<00:00,  8.20it/s]

# %%
latent_vectors025
# Out:
# array([[ 0.5221261 , -0.16633981, -0.23574312],
#        [ 0.54431856, -0.2179131 , -0.3561309 ],
#        [ 0.47085628, -0.20824738,  0.07771968],
#        ...,
#        [-0.17907964, -0.29214525, -0.22341932],
#        [-0.14820914, -0.19407578, -0.3672758 ],
#        [-0.05607806, -0.12633868, -0.52577704]], dtype=float32)

# %%
# 잠재벡터 분포 확인
# 박스플롯 및 바이올린 플롯 그리기
plt.figure(figsize=(14, 6))

# 박스플롯
plt.subplot(1, 2, 1)
plt.boxplot(latent_vectors025, vert=True, patch_artist=True)
plt.xlabel('Latent Vector Dimensions')
plt.ylabel('Values')
plt.title('Boxplot of Latent Vectors')
plt.grid(True)

# 바이올린 플롯
plt.subplot(1, 2, 2)
sns.violinplot(data=latent_vectors025, orient='v')
plt.xlabel('Latent Vector Dimensions')
plt.ylabel('Values')
plt.title('Violin Plot of Latent Vectors')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
mean_vector025
# Out:
# array([ 0.16126059, -0.01338427, -0.19044681], dtype=float32)

# %%
cov_matrix025
# Out:
# array([[ 0.01734737, -0.00782464, -0.00941973],
#        [-0.00782464,  0.02010076, -0.0069129 ],
#        [-0.00941973, -0.0069129 ,  0.03282934]], dtype=float32)

# %%
inv_cov_matrix025
# Out:
# array([[105.42924 ,  55.4605  ,  41.92918 ],
#        [ 55.4605  ,  82.808075,  33.35024 ],
#        [ 41.92918 ,  33.35024 ,  49.513885]], dtype=float32)

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 10.5)
arl
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]/var/folders/fs/s6wbqnkj5w33bczyrx_fzrn00000gn/T/ipykernel_87459/3125311034.py:20: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:277.)
#   x = torch.FloatTensor([y]).to(device)
# 100%|██████████| 10000/10000 [23:02<00:00,  7.23it/s]
# 983.3042

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 11)
arl
# Out:
# 100%|██████████| 10000/10000 [12:21<00:00, 13.48it/s]
# 665.1043

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 10)
arl
# Out:
# 100%|██████████| 10000/10000 [11:58<00:00, 13.92it/s]
# 498.8945

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 9.5)
arl
# Out:
# 100%|██████████| 10000/10000 [07:01<00:00, 23.71it/s]
# 285.7832

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 9.78)
arl
# Out:
# 100%|██████████| 10000/10000 [09:19<00:00, 17.88it/s]
# 389.212

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 9.7)
arl
# Out:
# 100%|██████████| 10000/10000 [08:21<00:00, 19.93it/s]
# 355.2062

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 9.75)
arl
# Out:
# 100%|██████████| 10000/10000 [08:53<00:00, 18.73it/s]
# 377.1187

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 9.735)
arl
# Out:
# 100%|██████████| 10000/10000 [08:54<00:00, 18.72it/s]
# 372.7809

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 9.7344)
arl
# Out:
# 100%|██████████| 10000/10000 [08:47<00:00, 18.95it/s]
# 368.3032

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 9.7346)
arl
# Out:
# 100%|██████████| 10000/10000 [08:51<00:00, 18.83it/s]
# 374.0194

# %%
arl, rl = arl_moving_window(ar = 0.25, delta = 0, gamma = 1, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 9.7345)
arl
# Out:
# 100%|██████████| 10000/10000 [08:31<00:00, 19.56it/s]
# 370.8777

# %%
# rl에 대한 히스토그램 생성
plt.figure(figsize=(10, 6))
plt.hist(rl, bins=50, color='blue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Run Lengths (RL)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
plt.grid(True)

# ARL 값을 히스토그램 위에 표시
plt.text(0.95, 0.95, f'ARL: {arl:.2f}', horizontalalignment='right', verticalalignment='top', transform=plt.gca().transAxes, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

plt.show()

# %%
# 잠재벡터 분포 확인
import seaborn as sns

plt.figure(figsize=(14, 6))
# 박스플롯
plt.subplot(1, 2, 1)
plt.boxplot(rl, vert=True, patch_artist=True)
plt.xlabel('ar = 0.25')
plt.ylabel('Values')
plt.title('Boxplot of ARL')
plt.grid(True)

# %% [markdown]
# ##### ARL1

# %%
arl1(ar = 0.25, run = 10000, mean_vector = mean_vector025, inv_cov_matrix = inv_cov_matrix025, cl = 9.7345)
# Out:
# 100%|██████████| 10000/10000 [01:02<00:00, 159.77it/s]
# 100%|██████████| 10000/10000 [00:10<00:00, 960.51it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 3005.90it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 3117.23it/s]
# 100%|██████████| 10000/10000 [00:39<00:00, 251.82it/s]
# 100%|██████████| 10000/10000 [00:11<00:00, 833.54it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 2793.67it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 3102.49it/s]
# 100%|██████████| 10000/10000 [01:47<00:00, 92.64it/s]
# 100%|██████████| 10000/10000 [00:52<00:00, 190.59it/s]
# 100%|██████████| 10000/10000 [00:26<00:00, 378.20it/s]
# 0.5: 44.53, 1:7.1853,2:2.0233,3:2.0
# 0.5:28.744,1:8.4423,2:2.2686,3:2.0
# 1.5:78.7787,2:38.3426,3:19.0843
